# %%
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
import pandas as pd
import boto3
import re
from sagemaker import get_execution_role
import os
import io
import time
import json
import sagemaker.amazon.common as smac
from sklearn.model_selection import train_test_split

bucket = 'qs-demo-bgf'
prefix = 'transformed-data-no-header'

role = get_execution_role()

# %%
#load data 
s3 = boto3.resource('s3')

KEY = prefix+'/transformed_data_no_header.csv'
print(KEY)

s3.Bucket(bucket).download_file(KEY, 'transformed_data_no_header.csv')
# Out:
# transformed-data-no-header/transformed_data_no_header.csv

# %%
covtype = pd.read_csv('transformed_data_no_header.csv',dtype='float32').values
print(covtype.shape)
covtype_features, covtype_labels = covtype[:, :2], covtype[:, 2]
np.random.seed(0)
train_features, test_features, train_labels, test_labels = train_test_split(
    covtype_features, covtype_labels, test_size=0.2)
# further split the test set into validation and test sets
val_features, test_features, val_labels, test_labels = train_test_split(
    test_features, test_labels, test_size=0.5)
# Out:
# (21817, 3)

# %%
print(train_features[0])
print(train_labels[0])
# Out:
# [ 5. 19.]
# 0.0

# %%
import sagemaker
from sagemaker.amazon.amazon_estimator import RecordSet
import boto3

# instantiate the LinearLearner estimator object
multiclass_estimator = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                               train_instance_count=1,
                                               train_instance_type='ml.m4.xlarge',
                                               predictor_type='multiclass_classifier',
                                               num_classes=3)

# %%
# wrap data in RecordSet objects
train_records = multiclass_estimator.record_set(train_features, train_labels, channel='train')
val_records = multiclass_estimator.record_set(val_features, val_labels, channel='validation')
test_records = multiclass_estimator.record_set(test_features, test_labels, channel='test')

# %%
# start a training job
multiclass_estimator.fit([train_records, val_records, test_records])
# Out:
# 2019-11-04 01:57:20 Starting - Starting the training job...
# 2019-11-04 01:57:22 Starting - Launching requested ML instances......
# 2019-11-04 01:58:21 Starting - Preparing the instances for training...
# 2019-11-04 01:59:19 Downloading - Downloading input data......
# 2019-11-04 02:00:17 Training - Training image download completed. Training in progress.
# 2019-11-04 02:00:17 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# [11/04/2019 02:00:14 INFO 140226076981056] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/04/2019 02:00:14 INFO 140226076981056] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'2', u'mini_batch_size': u'1000', u'predictor_type': u'multiclass_classifier', u'num_classes': u'3'}
# [11/04/2019 02:00:14 INFO 140226076981056] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'2', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'3', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/04/2019 02:00:14 WARNING 140226076981056] Loggers have already been setup.
# Process 1 is a worker.
# [11/04/2019 02:00:14 INFO 140226076981056] Using default worker.
# [2019-11-04 02:00:14.383] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-11-04 02:00:14.386] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-11-04 02:00:14.409] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 30, "num_examples": 1, "num_bytes": 52000}
# [11/04/2019 02:00:14 INFO 140226076981056] Create Store: local
# [2019-11-04 02:00:14.455] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 44, "num_examples": 11, "num_bytes": 572000}
# [11/04/2019 02:00:14 INFO 140226076981056] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7

#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.25055552097114264, "sum": 0.25055552097114264, "min": 0.25055552097114264}}, "EndTime": 1572832814.860323, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1572832814.860314}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.26094080350685295, "sum": 0.26094080350685295, "min": 0.26094080350685295}}, "EndTime": 1572832814.860372, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1572832814.860356}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24676232726938893, "sum": 0.24676232726938893, "min": 0.24676232726938893}}, "EndTime": 1572832814.860433, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1572832814.860417}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24915428231551381, "sum": 0.24915428231551381, "min": 0.24915428231551381}}, "EndTime": 1572832814.860491, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1572832814.860474}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24030794341229825, "sum": 0.24030794341229825, "min": 0.24030794341229825}}, "EndTime": 1572832814.86055, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1572832814.860539}
#
# [11/04/2019 02:00:14 INFO 140226076981056] #quality_metric: host=algo-1, epoch=0, validation multiclass_cross_entropy_objective <loss>=0.264204988558
# [11/04/2019 02:00:14 INFO 140226076981056] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=multiclass_cross_entropy_objective, value=0.240307943412
# [11/04/2019 02:00:14 INFO 140226076981056] Epoch 0: Loss improved. Updating best model
# [11/04/2019 02:00:14 INFO 140226076981056] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Batches Since Last Reset": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Records Since Last Reset": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Total Batches Seen": {"count": 1, "max": 30, "sum": 30.0, "min": 30}, "Total Records Seen": {"count": 1, "max": 29453, "sum": 29453.0, "min": 29453}, "Max Records Seen Between Resets": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1572832814.862208, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1572832814.540481}
#
# [11/04/2019 02:00:14 INFO 140226076981056] #throughput_metric: host=algo-1, train throughput=54226.4713749 records/second
# [2019-11-04 02:00:15.123] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 261, "num_examples": 18, "num_bytes": 907556}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.25553682125315946, "sum": 0.25553682125315946, "min": 0.25553682125315946}}, "EndTime": 1572832815.124022, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.123947}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.26244673964556525, "sum": 0.26244673964556525, "min": 0.26244673964556525}}, "EndTime": 1572832815.124121, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.124101}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2668423874798943, "sum": 0.2668423874798943, "min": 0.2668423874798943}}, "EndTime": 1572832815.124189, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.12417}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.26623227197983684, "sum": 0.26623227197983684, "min": 0.26623227197983684}}, "EndTime": 1572832815.124249, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.124232}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5569500804227941, "sum": 0.5569500804227941, "min": 0.5569500804227941}}, "EndTime": 1572832815.124308, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.12429}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6371406429515165, "sum": 0.6371406429515165, "min": 0.6371406429515165}}, "EndTime": 1572832815.124372, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.124353}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.35052035163430606, "sum": 0.35052035163430606, "min": 0.35052035163430606}}, "EndTime": 1572832815.124435, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.124417}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24644219970703124, "sum": 0.24644219970703124, "min": 0.24644219970703124}}, "EndTime": 1572832815.124499, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.124482}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24041636119169346, "sum": 0.24041636119169346, "min": 0.24041636119169346}}, "EndTime": 1572832815.124563, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.124546}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.256376049266142, "sum": 0.256376049266142, "min": 0.256376049266142}}, "EndTime": 1572832815.124627, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.124609}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24027383781881895, "sum": 0.24027383781881895, "min": 0.24027383781881895}}, "EndTime": 1572832815.124685, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.124669}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23289969141343062, "sum": 0.23289969141343062, "min": 0.23289969141343062}}, "EndTime": 1572832815.124747, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.124728}
#
# [11/04/2019 02:00:15 INFO 140226076981056] #quality_metric: host=algo-1, epoch=1, train multiclass_cross_entropy_objective <loss>=0.255536821253
# [2019-11-04 02:00:15.163] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 28, "num_examples": 3, "num_bytes": 113464}
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2591010494913998, "sum": 0.2591010494913998, "min": 0.2591010494913998}}, "EndTime": 1572832815.166417, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.166372}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2549176063152981, "sum": 0.2549176063152981, "min": 0.2549176063152981}}, "EndTime": 1572832815.166499, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.166477}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.25734154048258834, "sum": 0.25734154048258834, "min": 0.25734154048258834}}, "EndTime": 1572832815.16657, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.166551}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24816513760826328, "sum": 0.24816513760826328, "min": 0.24816513760826328}}, "EndTime": 1572832815.166639, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.16662}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.4495134537204704, "sum": 0.4495134537204704, "min": 0.4495134537204704}}, "EndTime": 1572832815.166705, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.166687}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5524888357692197, "sum": 0.5524888357692197, "min": 0.5524888357692197}}, "EndTime": 1572832815.16677, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.166752}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2982394553236083, "sum": 0.2982394553236083, "min": 0.2982394553236083}}, "EndTime": 1572832815.166839, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.16682}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.258384900394653, "sum": 0.258384900394653, "min": 0.258384900394653}}, "EndTime": 1572832815.166934, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.16689}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.25016247603349134, "sum": 0.25016247603349134, "min": 0.25016247603349134}}, "EndTime": 1572832815.167002, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.166983}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2708853871094645, "sum": 0.2708853871094645, "min": 0.2708853871094645}}, "EndTime": 1572832815.167069, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.16705}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2538865279102413, "sum": 0.2538865279102413, "min": 0.2538865279102413}}, "EndTime": 1572832815.167131, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.167114}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24667701930982272, "sum": 0.24667701930982272, "min": 0.24667701930982272}}, "EndTime": 1572832815.167194, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832815.167176}
#
# [11/04/2019 02:00:15 INFO 140226076981056] #quality_metric: host=algo-1, epoch=1, validation multiclass_cross_entropy_objective <loss>=0.259101049491
# [11/04/2019 02:00:15 INFO 140226076981056] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=multiclass_cross_entropy_objective, value=0.24667701931
# [11/04/2019 02:00:15 INFO 140226076981056] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Batches Since Last Reset": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Records Since Last Reset": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Total Batches Seen": {"count": 1, "max": 48, "sum": 48.0, "min": 48}, "Total Records Seen": {"count": 1, "max": 46906, "sum": 46906.0, "min": 46906}, "Max Records Seen Between Resets": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1572832815.16806, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1572832814.862473}
#
# [11/04/2019 02:00:15 INFO 140226076981056] #throughput_metric: host=algo-1, train throughput=57087.4114575 records/second
# [2019-11-04 02:00:15.421] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 253, "num_examples": 18, "num_bytes": 907556}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2364905413459329, "sum": 0.2364905413459329, "min": 0.2364905413459329}}, "EndTime": 1572832815.42172, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1572832815.421669}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2353079376220703, "sum": 0.2353079376220703, "min": 0.2353079376220703}}, "EndTime": 1572832815.421793, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1572832815.421779}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23856394150677848, "sum": 0.23856394150677848, "min": 0.23856394150677848}}, "EndTime": 1572832815.421833, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1572832815
#progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Batches Since Last Reset": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Records Since Last Reset": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Total Batches Seen": {"count": 1, "max": 66, "sum": 66.0, "min": 66}, "Total Records Seen": {"count": 1, "max": 64359, "sum": 64359.0, "min": 64359}, "Max Records Seen Between Resets": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1572832815.464297, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1572832815.168365}
#
# [11/04/2019 02:00:15 INFO 140226076981056] #throughput_metric: host=algo-1, train throughput=58944.1308954 records/second
# [2019-11-04 02:00:15.717] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 252, "num_examples": 18, "num_bytes": 907556}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2321237092859605, "sum": 0.2321237092859605, "min": 0.2321237092859605}}, "EndTime": 1572832815.717602, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.717528}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.232369873046875, "sum": 0.232369873046875, "min": 0.232369873046875}}, "EndTime": 1572832815.7177, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.717683}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23188835592830884, "sum": 0.23188835592830884, "min": 0.23188835592830884}}, "EndTime": 1572832815.717753, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.71774}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23202492747587317, "sum": 0.23202492747587317, "min": 0.23202492747587317}}, "EndTime": 1572832815.717804, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.717792}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.309691801183364, "sum": 0.309691801183364, "min": 0.309691801183364}}, "EndTime": 1572832815.717852, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.71784}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3882894753848805, "sum": 0.3882894753848805, "min": 0.3882894753848805}}, "EndTime": 1572832815.717898, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.717886}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24102241067325367, "sum": 0.24102241067325367, "min": 0.24102241067325367}}, "EndTime": 1572832815.717945, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.717933}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23134640054141775, "sum": 0.23134640054141775, "min": 0.23134640054141775}}, "EndTime": 1572832815.71799, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.717979}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2330660400390625, "sum": 0.2330660400390625, "min": 0.2330660400390625}}, "EndTime": 1572832815.718036, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.718024}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.27230036297966453, "sum": 0.27230036297966453, "min": 0.27230036297966453}}, "EndTime": 1572832815.718082, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.71807}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2317907086540671, "sum": 0.2317907086540671, "min": 0.2317907086540671}}, "EndTime": 1572832815.718127, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.718116}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24207502567066866, "sum": 0.24207502567066866, "min": 0.24207502567066866}}, "EndTime": 1572832815.718178, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.718168}
#
# [11/04/2019 02:00:15 INFO 140226076981056] #quality_metric: host=algo-1, epoch=3, train multiclass_cross_entropy_objective <loss>=0.232123709286
# [2019-11-04 02:00:15.753] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 11, "duration": 27, "num_examples": 3, "num_bytes": 113464}
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24033449943955068, "sum": 0.24033449943955068, "min": 0.24033449943955068}}, "EndTime": 1572832815.756715, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.756671}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24096661505624856, "sum": 0.24096661505624856, "min": 0.24096661505624856}}, "EndTime": 1572832815.756792, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.756774}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24077951481973875, "sum": 0.24077951481973875, "min": 0.24077951481973875}}, "EndTime": 1572832815.756861, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.756848}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24067344805387922, "sum": 0.24067344805387922, "min": 0.24067344805387922}}, "EndTime": 1572832815.756916, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.756899}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2940289770977744, "sum": 0.2940289770977744, "min": 0.2940289770977744}}, "EndTime": 1572832815.756983, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.756965}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3535430062046628, "sum": 0.3535430062046628, "min": 0.3535430062046628}}, "EndTime": 1572832815.757058, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.757038}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24490195780473495, "sum": 0.24490195780473495, "min": 0.24490195780473495}}, "EndTime": 1572832815.757135, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.757115}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2403875975079978, "sum": 0.2403875975079978, "min": 0.2403875975079978}}, "EndTime": 1572832815.757207, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.757188}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.241355541099877, "sum": 0.241355541099877, "min": 0.241355541099877}}, "EndTime": 1572832815.757269, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.757251}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.25239541309891655, "sum": 0.25239541309891655, "min": 0.25239541309891655}}, "EndTime": 1572832815.757331, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.757314}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24027671953825422, "sum": 0.24027671953825422, "min": 0.24027671953825422}}, "EndTime": 1572832815.757402, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.757385}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2417979218564265, "sum": 0.2417979218564265, "min": 0.2417979218564265}}, "EndTime": 1572832815.757466, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.757449}
#
# [11/04/2019 02:00:15 INFO 140226076981056] #quality_metric: host=algo-1, epoch=3, validation multiclass_cross_entropy_objective <loss>=0.24033449944
# [11/04/2019 02:00:15 INFO 140226076981056] #early_stopping_criteria_metric: host=algo-1, epoch=3, criteria=multiclass_cross_entropy_objective, value=0.240276719538
# [11/04/2019 02:00:15 INFO 140226076981056] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Batches Since Last Reset": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Records Since Last Reset": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Total Batches Seen": {"count": 1, "max": 84, "sum": 84.0, "min": 84}, "Total Records Seen": {"count": 1, "max": 81812, "sum": 81812.0, "min": 81812}, "Max Records Seen Between Resets": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1572832815.758219, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1572832815.464627}
#
# [11/04/2019 02:00:15 INFO 140226076981056] #throughput_metric: host=algo-1, train throughput=59416.2909713 records/second
# [2019-11-04 02:00:16.024] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 266, "num_examples": 18, "num_bytes": 907556}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23122171379538142, "sum": 0.23122171379538142, "min": 0.23122171379538142}}, "EndTime": 1572832816.025286, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.025177}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2312349288042854, "sum": 0.2312349288042854, "min": 0.2312349288042854}}, "EndTime": 1572832816.025569, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.025543}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23155242650649127, "sum": 0.23155242650649127, "min": 0.23155242650649127}}, "EndTime": 1572832816.025668, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.025649}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2311696220846737, "sum": 0.2311696220846737, "min": 0.2311696220846737}}, "EndTime": 1572832816.025734, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.025719}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.27490291281307444, "sum": 0.27490291281307444, "min": 0.27490291281307444}}, "EndTime": 1572832816.025784, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.025772}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.32153881297392006, "sum": 0.32153881297392006, "min": 0.32153881297392006}}, "EndTime": 1572832816.025868, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.025853}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23384903043859145, "sum": 0.23384903043859145, "min": 0.23384903043859145}}, "EndTime": 1572832816.025922, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.025906}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2312927667954389, "sum": 0.2312927667954389, "min": 0.2312927667954389}}, "EndTime": 1572832816.026006, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.025988}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2314346825094784, "sum": 0.2314346825094784, "min": 0.2314346825094784}}, "EndTime": 1572832816.026058, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.026046}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.27405282503015854, "sum": 0.27405282503015854, "min": 0.27405282503015854}}, "EndTime": 1572832816.026104, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.026092}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2311651054831112, "sum": 0.2311651054831112, "min": 0.2311651054831112}}, "EndTime": 1572832816.026182, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.026167}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24256104323443245, "sum": 0.24256104323443245, "min": 0.24256104323443245}}, "EndTime": 1572832816.026232, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.02622}
#
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, epoch=4, train multiclass_cross_entropy_objective <loss>=0.231221713795
# [2019-11-04 02:00:16.074] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 14, "duration": 37, "num_examples": 3, "num_bytes": 113464}
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24053599132953926, "sum": 0.24053599132953926, "min": 0.24053599132953926}}, "EndTime": 1572832816.077304, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.077254}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24023914249745343, "sum": 0.24023914249745343, "min": 0.24023914249745343}}, "EndTime": 1572832816.077397, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.077375}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2405295629877218, "sum": 0.2405295629877218, "min": 0.2405295629877218}}, "EndTime": 1572832816.077468, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.077449}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2402865832055194, "sum": 0.2402865832055194, "min": 0.2402865832055194}}, "EndTime": 1572832816.077534, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.077515}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.27173250514798813, "sum": 0.27173250514798813, "min": 0.27173250514798813}}, "EndTime": 1572832816.077598, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.07758}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.30243420622744327, "sum": 0.30243420622744327, "min": 0.30243420622744327}}, "EndTime": 1572832816.077654, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.077637}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24141581751249122, "sum": 0.24141581751249122, "min": 0.24141581751249122}}, "EndTime": 1572832816.077717, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.0777}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24033063753933998, "sum": 0.24033063753933998, "min": 0.24033063753933998}}, "EndTime": 1572832816.077786, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.077769}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24072290974729768, "sum": 0.24072290974729768, "min": 0.24072290974729768}}, "EndTime": 1572832816.077855, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.077837}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24852244816822922, "sum": 0.24852244816822922, "min": 0.24852244816822922}}, "EndTime": 1572832816.077917, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.0779}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24024299041160632, "sum": 0.24024299041160632, "min": 0.24024299041160632}}, "EndTime": 1572832816.077981, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.077962}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2472708655758586, "sum": 0.2472708655758586, "min": 0.2472708655758586}}, "EndTime": 1572832816.078049, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832816.07803}
#
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, epoch=4, validation multiclass_cross_entropy_objective <loss>=0.24053599133
# [11/04/2019 02:00:16 INFO 140226076981056] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=multiclass_cross_entropy_objective, value=0.240239142497
# [11/04/2019 02:00:16 INFO 140226076981056] Early stop condition met. Stopping training.
# [11/04/2019 02:00:16 INFO 140226076981056] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Batches Since Last Reset": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Records Since Last Reset": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Total Batches Seen": {"count": 1, "max": 102, "sum": 102.0, "min": 102}, "Total Records Seen": {"count": 1, "max": 99265, "sum": 99265.0, "min": 99265}, "Max Records Seen Between Resets": {"count": 1, "max": 17453, "sum": 17453.0, "min": 17453}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1572832816.079006, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1572832815.758516}
#
# [11/04/2019 02:00:16 INFO 140226076981056] #throughput_metric: host=algo-1, train throughput=54431.9490563 records/second
# [11/04/2019 02:00:16 WARNING 140226076981056] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/04/2019 02:00:16 WARNING 140226076981056] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-11-04 02:00:16.125] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 17, "duration": 37, "num_examples": 3, "num_bytes": 113464}
# [11/04/2019 02:00:16 INFO 140226076981056] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=multiclass_cross_entropy_objective, value=0.240239142497
# [2019-11-04 02:00:16.166] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 19, "duration": 33, "num_examples": 3, "num_bytes": 113464}
# [11/04/2019 02:00:16 INFO 140226076981056] #validation_score (algo-1) : ('multiclass_cross_entropy_objective', 0.24030794341229825)
# [11/04/2019 02:00:16 INFO 140226076981056] #validation_score (algo-1) : ('multiclass_accuracy', 0.9454628780934922)
# [11/04/2019 02:00:16 INFO 140226076981056] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [11/04/2019 02:00:16 INFO 140226076981056] #validation_score (algo-1) : ('dcg', 0.9783118621238758)
# [11/04/2019 02:00:16 INFO 140226076981056] #validation_score (algo-1) : ('macro_recall', 0.33333334)
# [11/04/2019 02:00:16 INFO 140226076981056] #validation_score (algo-1) : ('macro_precision', nan)
# [11/04/2019 02:00:16 INFO 140226076981056] #validation_score (algo-1) : ('macro_f_1.000', 0.323989)
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, validation multiclass_cross_entropy_objective <loss>=0.240307943412
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.945462878093
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=1.0
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, validation dcg <score>=0.978311862124
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, validation macro_recall <score>=0.333333343267
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, validation macro_precision <score>=nan
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.323989003897
# [11/04/2019 02:00:16 INFO 140226076981056] Best model found for hyperparameters: {"lr_scheduler_step": 13, "wd": 0.015379086140622243, "optimizer": "rmsprop", "lr_scheduler_factor": 0.9921646722873575, "l1": 0.12007663993206846, "learning_rate": 0.06728804607670545, "lr_scheduler_minimum_lr": 0.0002903886846508794}
# [11/04/2019 02:00:16 INFO 140226076981056] Saved checkpoint to "/tmp/tmpoe5CkO/mx-mod-0000.params"
# [2019-11-04 02:00:16.216] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 1830, "num_examples": 1, "num_bytes": 52000}
# [2019-11-04 02:00:16.250] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 34, "num_examples": 3, "num_bytes": 113464}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 2182, "sum": 2182.0, "min": 2182}, "Total Batches Seen": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Total Records Seen": {"count": 1, "max": 2182, "sum": 2182.0, "min": 2182}, "Max Records Seen Between Resets": {"count": 1, "max": 2182, "sum": 2182.0, "min": 2182}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1572832816.279941, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1572832816.216084}
#
# [11/04/2019 02:00:16 INFO 140226076981056] #test_score (algo-1) : ('multiclass_cross_entropy_objective', 0.24314293655968935)
# [11/04/2019 02:00:16 INFO 140226076981056] #test_score (algo-1) : ('multiclass_accuracy', 0.9440879926672777)
# [11/04/2019 02:00:16 INFO 140226076981056] #test_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [11/04/2019 02:00:16 INFO 140226076981056] #test_score (algo-1) : ('dcg', 0.9779844555037487)
# [11/04/2019 02:00:16 INFO 140226076981056] #test_score (algo-1) : ('macro_recall', 0.33333334)
# [11/04/2019 02:00:16 INFO 140226076981056] #test_score (algo-1) : ('macro_precision', nan)
# [11/04/2019 02:00:16 INFO 140226076981056] #test_score (algo-1) : ('macro_f_1.000', 0.32374665)
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, test multiclass_cross_entropy_objective <loss>=0.24314293656
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, test multiclass_accuracy <score>=0.944087992667
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, test multiclass_top_k_accuracy_3 <score>=1.0
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, test dcg <score>=0.977984455504
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, test macro_recall <score>=0.333333343267
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, test macro_precision <score>=nan
# [11/04/2019 02:00:16 INFO 140226076981056] #quality_metric: host=algo-1, test macro_f_1.000 <score>=0.323746651411
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1992.9301738739014, "sum": 1992.9301738739014, "min": 1992.9301738739014}, "finalize.time": {"count": 1, "max": 114.99214172363281, "sum": 114.99214172363281, "min": 114.99214172363281}, "initialize.time": {"count": 1, "max": 149.28293228149414, "sum": 149.28293228149414, "min": 149.28293228149414}, "check_early_stopping.time": {"count": 6, "max": 0.8640289306640625, "sum": 2.0592212677001953, "min": 0.21409988403320312}, "setuptime": {"count": 1, "max": 27.84419059753418, "sum": 27.84419059753418, "min": 27.84419059753418}, "update.time": {"count": 5, "max": 321.5339183807373, "sum": 1536.271095275879, "min": 293.4300899505615}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1572832816.289226, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1572832814.37908}
# 2019-11-04 02:00:24 Completed - Training job completed
# Training seconds: 65
# Billable seconds: 65

# %%
# deploy a model hosting endpoint
multiclass_predictor = multiclass_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# --------------------------------------------------------------------------------------------------!

# %%
area = {"Queens":1.0,
"Staten Island":2.0,
"Brooklyn":3.0,
"Bronx":4.0,
"Manhattan":5.0}

cat = {
    "Hotdogs/Pretzels":1.0,
    "Donuts":2.0,
    "Bangladeshi":3.0,
    "Caribbean":4.0,
    "Chicken":5.0,
    "English":6.0,
    "Pizza":7.0,
    "Vegetarian":8.0,
    "Irish":9.0,
    "Not Listed/Not Applicable":10.0
}

# %%
import json 
import boto3 
client = boto3.client('runtime.sagemaker')

region = area["Manhattan"]
category = 54

values = str(region)+','+str(category)

response = client.invoke_endpoint(EndpointName='linear-learner-2019-11-04-01-57-20-572',
                                  ContentType='text/csv',
                                  Body=values)
result = json.loads(response['Body'].read().decode())

predict = result['predictions'][0]
print(predict)

grade = predict['predicted_label']

if(grade==0.0):
    letter = "A"
elif(grade==1.0):
    letter = "B"
else:
    letter = "C"
    
print("\nRestaurant Grade: "+letter)
# Out:
# {'score': [0.9371309280395508, 0.048006024211645126, 0.014863001182675362], 'predicted_label': 0.0}
#
# Restaurant Grade: A
